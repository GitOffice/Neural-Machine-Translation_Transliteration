# %%
# !ls
# Out:
# aEmbedding.txt	 Arabic.xml	   English.xml		 French.txt
# ArabicModel.bin  EnglishModel.bin  fasttextCommands.txt  French.xml
# ArabicModel.vec  EnglishModel.vec  FrenchModel.bin	 readEmbedding.ipynb
# Arabic.txt	 English.txt	   FrenchModel.vec	 XMLparser.ipynb

# %% [markdown]
# ### Reading and Writing Files in Python
# http://www.pythonforbeginners.com/files/reading-and-writing-files-in-python

# %%
embedding = ''
with open('aEmbedding.txt', 'r') as file:
    embedding = file.read()

# %%
embedding = embedding.rstrip().split()

# %%
embedding
# Out:
# ['a',
#  '0.40506',
#  '0.37352',
#  '-0.23617',
#  '0.22228',
#  '-0.033054',
#  '0.3463',
#  '-0.3313',
#  '0.080508',
#  '-0.47959',
#  '0.11837',
#  '0.30762',
#  '0.47989',
#  '-0.57912',
#  '-0.076107',
#  '-0.16782',
#  '0.2678',
#  '0.36345',
#  '-0.071637',
#  '-0.23934',
#  '-0.14182',
#  '-0.16822',
#  '-0.34292',
#  '0.29032',
#  '0.47945',
#  '0.18915',
#  '-0.37318',
#  '0.008474',
#  '-0.07937',
#  '0.003018',
#  '-0.075383',
#  '-0.0023912',
#  '-0.19829',
#  '-0.24209',
#  '0.15',
#  '-0.59825',
#  '0.22619',
#  '0.01011',
#  '0.17971',
#  '0.046534',
#  '-0.18606',
#  '-0.4259',
#  '0.2583',
#  '-0.26919',
#  '0.77879',
#  '0.10401',
#  '-0.44479',
#  '0.12035',
#  '0.51547',
#  '0.2563',
#  '0.38395',
#  '0.2485',
#  '0.23691',
#  '-0.33098',
#  '-0.35039',
#  '0.018037',
#  '-0.82082',
#  '-0.51657',
#  '-0.038358',
#  '-0.43592',
#  '0.28361',
#  '-0.013877',
#  '-0.086546',
#  '0.43124',
#  '-0.066933',
#  '-0.1715',
#  '0.45411',
#  '0.29674',
#  '0.28956',
#  '-0.053122',
#  '0.4015',
#  '-0.058103',
#  '0.027427',
#  '0.23801',
#  '0.052242',
#  '-0.2286',
#  '0.080568',
#  '0.18723',
#  '0.47542',
#  '-0.066313',
#  '-0.54353',
#  '0.22093',
#  '-0.13573',
#  '0.30506',
#  '0.14078',
#  '0.55538',
#  '0.28377',
#  '0.10705',
#  '0.27597',
#  '-0.040759',
#  '-0.72144',
#  '0.23622',
#  '0.044831',
#  '0.16618',
#  '0.071171',
#  '0.0555',
#  '-0.12734',
#  '-0.14115',
#  '0.35177',
#  '0.32892',
#  '-0.15645']

# %%
del embedding[0]

# %%
embedding
# Out:
# ['0.40506',
#  '0.37352',
#  '-0.23617',
#  '0.22228',
#  '-0.033054',
#  '0.3463',
#  '-0.3313',
#  '0.080508',
#  '-0.47959',
#  '0.11837',
#  '0.30762',
#  '0.47989',
#  '-0.57912',
#  '-0.076107',
#  '-0.16782',
#  '0.2678',
#  '0.36345',
#  '-0.071637',
#  '-0.23934',
#  '-0.14182',
#  '-0.16822',
#  '-0.34292',
#  '0.29032',
#  '0.47945',
#  '0.18915',
#  '-0.37318',
#  '0.008474',
#  '-0.07937',
#  '0.003018',
#  '-0.075383',
#  '-0.0023912',
#  '-0.19829',
#  '-0.24209',
#  '0.15',
#  '-0.59825',
#  '0.22619',
#  '0.01011',
#  '0.17971',
#  '0.046534',
#  '-0.18606',
#  '-0.4259',
#  '0.2583',
#  '-0.26919',
#  '0.77879',
#  '0.10401',
#  '-0.44479',
#  '0.12035',
#  '0.51547',
#  '0.2563',
#  '0.38395',
#  '0.2485',
#  '0.23691',
#  '-0.33098',
#  '-0.35039',
#  '0.018037',
#  '-0.82082',
#  '-0.51657',
#  '-0.038358',
#  '-0.43592',
#  '0.28361',
#  '-0.013877',
#  '-0.086546',
#  '0.43124',
#  '-0.066933',
#  '-0.1715',
#  '0.45411',
#  '0.29674',
#  '0.28956',
#  '-0.053122',
#  '0.4015',
#  '-0.058103',
#  '0.027427',
#  '0.23801',
#  '0.052242',
#  '-0.2286',
#  '0.080568',
#  '0.18723',
#  '0.47542',
#  '-0.066313',
#  '-0.54353',
#  '0.22093',
#  '-0.13573',
#  '0.30506',
#  '0.14078',
#  '0.55538',
#  '0.28377',
#  '0.10705',
#  '0.27597',
#  '-0.040759',
#  '-0.72144',
#  '0.23622',
#  '0.044831',
#  '0.16618',
#  '0.071171',
#  '0.0555',
#  '-0.12734',
#  '-0.14115',
#  '0.35177',
#  '0.32892',
#  '-0.15645']

# %%
embedding = [float(value) for value in embedding]

# %%
embedding
# Out:
# [0.40506,
#  0.37352,
#  -0.23617,
#  0.22228,
#  -0.033054,
#  0.3463,
#  -0.3313,
#  0.080508,
#  -0.47959,
#  0.11837,
#  0.30762,
#  0.47989,
#  -0.57912,
#  -0.076107,
#  -0.16782,
#  0.2678,
#  0.36345,
#  -0.071637,
#  -0.23934,
#  -0.14182,
#  -0.16822,
#  -0.34292,
#  0.29032,
#  0.47945,
#  0.18915,
#  -0.37318,
#  0.008474,
#  -0.07937,
#  0.003018,
#  -0.075383,
#  -0.0023912,
#  -0.19829,
#  -0.24209,
#  0.15,
#  -0.59825,
#  0.22619,
#  0.01011,
#  0.17971,
#  0.046534,
#  -0.18606,
#  -0.4259,
#  0.2583,
#  -0.26919,
#  0.77879,
#  0.10401,
#  -0.44479,
#  0.12035,
#  0.51547,
#  0.2563,
#  0.38395,
#  0.2485,
#  0.23691,
#  -0.33098,
#  -0.35039,
#  0.018037,
#  -0.82082,
#  -0.51657,
#  -0.038358,
#  -0.43592,
#  0.28361,
#  -0.013877,
#  -0.086546,
#  0.43124,
#  -0.066933,
#  -0.1715,
#  0.45411,
#  0.29674,
#  0.28956,
#  -0.053122,
#  0.4015,
#  -0.058103,
#  0.027427,
#  0.23801,
#  0.052242,
#  -0.2286,
#  0.080568,
#  0.18723,
#  0.47542,
#  -0.066313,
#  -0.54353,
#  0.22093,
#  -0.13573,
#  0.30506,
#  0.14078,
#  0.55538,
#  0.28377,
#  0.10705,
#  0.27597,
#  -0.040759,
#  -0.72144,
#  0.23622,
#  0.044831,
#  0.16618,
#  0.071171,
#  0.0555,
#  -0.12734,
#  -0.14115,
#  0.35177,
#  0.32892,
#  -0.15645]
